# %% [markdown]
# # Lecture 6 - Data  Visualisation

# %% [markdown]
# ### Assignment 1.0
# Import Pandas, import the CSV <b>'weather_aus.csv'</b> file as you did in the previous assignment. Generate few visualisations to explore the dataset. Use the following plots to explore the data.
# 1. BoxPlot
# 2. Histogram
# 3. Scatter Plot
# 4. Correlation Matrix
#
# <b> Hint </b>
#
# The weather dataset contains weather data that belongs to many cities. So choose that weather data the belongs to a city (e.g. Canberra) and one of the data attributes (such as MinTemp or MaxTemp etc.) for generating the visualisations. For example, the following code selects the MinTemp and MaxTemp of weather data that belongs to Canberra.
#
# ```python
# import matplotlib.pyplot as plt
#
# can_min_temp = df.loc[df['Location'] == 'Canberra']['MinTemp']
#
# can_max_temp = df.loc[df['Location'] == 'Canberra']['MaxTemp']
#
# ```

# %%
import pandas as pd 
import matplotlib.pyplot as plt
w_aus = pd.read_csv('weather_aus.csv')
w_aus.plot()
plt.show()

# %%
print(w_aus)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 142188       NaN           E           31.0        ESE  ...        59.0
# 142189       NaN           E           31.0         SE  ...        51.0
# 142190       NaN         NNW           22.0         SE  ...        56.0
# 142191       NaN           N           37.0         SE  ...        53.0
# 142192       NaN          SE           28.0        SSE  ...        51.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 142188         27.0       1024.7       1021.2       NaN       NaN      9.4
# 142189         24.0       1024.6       1020.3       NaN       NaN     10.1
# 142190         21.0       1023.5       1019.1       NaN       NaN     10.9
# 142191         24.0       1021.0       1016.8       NaN       NaN     12.5
# 142192         24.0       1019.4       1016.5       3.0       2.0     15.1
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 142188     20.9         No            No
# 142189     22.4         No            No
# 142190     24.5         No            No
# 142191     26.1         No            No
# 142192     26.0         No            No
#
# [142193 rows x 23 columns]

# %%
w_aus['MaxTemp'].plot(kind = 'box')

# %%
w_aus.plot(x = 'Date', y = 'MaxTemp' ,kind='scatter')
plt.show()

# %%
import matplotlib.pyplot as plt

can_min_temp = w_aus.loc[w_aus['Location'] == 'Canberra']['MinTemp']

can_max_temp = w_aus.loc[w_aus['Location'] == 'Canberra']['MaxTemp']
print(can_min_temp)
# Out:
# 44351     8.0
# 44352    14.0
# 44353    13.7
# 44354    13.3
# 44355     7.6
#          ...
# 47764    -2.4
# 47765    -0.4
# 47766    -2.9
# 47767     0.1
# 47768    -4.3
# Name: MinTemp, Length: 3418, dtype: float64

# %%
can_min_temp.plot()
plt.show()

# %%
w_aus.plot(x="Date", y = 'MinTemp')
